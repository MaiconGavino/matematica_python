# %% [markdown]
# <a href="https://colab.research.google.com/github/MaiconGavino/matematica_python/blob/master/Aula_2_Curso_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Curso de PYTHON - Introdução a Linguagem de Programação
#
# Este notebook é referente a segunda aula do curso de python, o mesmo será disponibilizado no final da aula para futuras consultas.
#
# Neste notebook, será Revisado os seguintes tópicos:
#
#
# *   Hello, World!
# *   Variável;
# *   Operações aritméticas;
# *   Entrada de Dados;
#
# Além disso serão realizado o seguinte tópicos:
#
# *   Exercícios de Fixação.
#
# #Vamos colocar a mão na massa!

# %%
#Função Print = apresenta na tela uma mensagem 

print("Hello, World!")
# Out:
# Hello, World!

# %%
#Variáveis 

nome = "Maicon Serrão"
idade = 23
print("meu nome é ", nome, "e eu tenho ", idade, "anos")
# Out:
# meu nome é  Maicon Serrão e eu tenho  23 anos

# %%
#Operações Aritmética 

# +, -, /, *, %, // 

valor1 = 10
valor2 = 3
print(valor1+valor2)
print(valor1*valor2)
print(valor1 % valor2)
print(valor1 // valor2)
# Out:
# 13
# 30
# 1
# 3

# %%
#Função Input
nome = input("Entre com o seu nome: ")
print("Seu nome é: ", nome)
# Out:
# Entre com o seu nome: maicon
# Seu nome é:  maicon

# %% [markdown]
# 1. Faça um Programa que mostre a mensagem "Alo mundo" na tela

# %%
#Função print
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# 2. Faça um Programa que peça um número e então mostre a mensagem O número informado foi [número].

# %%
num = input("Informe um valor: ")
print("O valor informado foi", num)
# Out:
# Informe um valor: 12564
# O valor informado foi 12564

# %% [markdown]
# 3. Faça um Programa que peça dois números e imprima a soma

# %%
num = int(input("Informe o primeiro valor: "))
num1 = int(input("Informe o segundo valor: "))
print(num+num1)
# Out:
# Informe o primeiro valor: 12565
# Informe o segundo valor: 326548
# 339113

# %% [markdown]
# 4. Faça um Programa que peça as 4 notas bimestrais e mostre a média.

# %%
nota1 = int(input("Informe a primeira nota: "))
nota2 = int(input("Informe a segunda nota: "))
nota3 = int(input("Informe a terceira  nota: "))
nota4 = int(input("Informe a quarta nota: "))
media = (nota1+nota2+nota3+nota4)/4
print("A media do aluno é",media)
# Out:
# Informe a primeira nota: 8
# Informe a segunda nota: 7
# Informe a terceira  nota: 4
# Informe a quarta nota: 9
# A media do aluno é 7.0

# %% [markdown]
# 5. Faça um Programa que converta metros para centímetros.

# %%
metro = int(input("Informe o valor em metros: "))
conv = metro *100
print("O valor de", metro, "metros é igual a ", conv, "centímetros")
# Out:
# Informe o valor em metros: 15
# O valor de 15 metros é igual a  1500 centímetros

# %% [markdown]
# 6. Faça um Programa que peça o raio de um círculo, calcule e mostre sua área

# %%
pi = 3.1415
raio = int(input("Informe o raio: "))
area = pi*raio *raio
area2 = pi*pow(raio, 2)
print(area)
print(area2)
# Out:
# Informe o raio: 4
# 50.264
# 50.264

# %% [markdown]
# 7. Faça um Programa que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

# %%
lado = int(input("Informe o lado do quadrado: "))
area = pow(lado, 2) #poderia utilizar area = lado*lado
dobro = area*2
print(dobro)
print(area*2)
# Out:
# Informe o lado do quadrado: 8
# 128
# 128

# %% [markdown]
# 8. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês

# %%
valor_hora = int(input("Informe o valor por hora trabalhada: "))
qtd_horas = int(input("Informe a quantidade de horas trabalhada: "))
salario = valor_hora * qtd_horas
print("Você ganha R$", salario, "por mês")
# Out:
# Informe o valor por hora trabalhada: 18
# Informe a quantidade de horas trabalhada: 120
# Você ganha R$ 2160 por mês

# %% [markdown]
# 9. Faça um Programa que peça a temperatura em graus Farenheit, transforme e mostre a temperatura em graus Celsius.
#
#     C = 5 * ((F-32) / 9).

# %%
farenheit = int(input("Informe a temperatura em graus farenheit: "))
cels = 5*((farenheit-32)/9)
print("A temperatura de ", farenheit, "graus farenheit é igual a ", cels, "graus celsius")
# Out:
# Informe a temperatura em graus farenheit: 16
# A temperatura de  16 graus farenheit é igual a  -8.88888888888889 graus celsius

# %% [markdown]
# 11. Desafio

# %% [markdown]
# ![
#
# ](https://)![image.png](data:image/png;base64,...)

# %%
import math #Importei o pacote matemática
degraus = int(input("Entre com a quantidade de degraus: "))
altura = int(input("Entre com o valor da altura: "))
largura = int(input("Entre com o valor da comprimento: "))
comprimento = int(input("Entre com o valor do largura: "))
diag = math.sqrt(pow(altura, 2)+ pow(largura,2))
area = (diag * comprimento * degraus)/10000
print(area)
# Out:
# Entre com a quantidade de degraus: 45
# Entre com o valor da altura: 4
# Entre com o valor da comprimento: 6
# Entre com o valor do largura: 45
# 1.4602482665629157
